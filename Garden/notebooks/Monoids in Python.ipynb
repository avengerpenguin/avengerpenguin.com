# %%
from typing import TypeVar, Generic
from abc import ABCMeta, abstractmethod


T = TypeVar('T')


class Monoid(Generic[T], metaclass=ABCMeta):

    @property
    @abstractmethod
    def identity(self) -> T: pass

    @abstractmethod
    def compose(self, x: T, y: T) -> T: pass
    
Monoid
# Out:
# __main__.Monoid

# %%
class IntMonoid(Monoid[int]):

    @property
    def identity(self):
        return 0

    def compose(self, x, y):
        return x + y

# %%
class StringMonoid(Monoid[str]):
    @property
    def identity(self):
        return ""

    def compose(self, x, y):
        return f"{y}{x}"

# %%
from hypothesis import given
from hypothesis.strategies import data, from_type
import pytest
from typing import get_args


monoids = [
    IntMonoid(),
    StringMonoid(),
]


@given(data())
@pytest.mark.parametrize("m", monoids)
def test_identity(m: Monoid[T], data):
    t = type(m.identity)

    x: T = data.draw(from_type(t))

    print(x, m.identity)
    assert x == m.compose(x, m.identity)
    assert x == m.compose(m.identity, x)


@given(data())    
@pytest.mark.parametrize("m", monoids)
def test_composition(m, data):
    t = type(m.identity)

    x: T = data.draw(from_type(t))
    y: T = data.draw(from_type(t))
    assert type(m.compose(x, y)) == t


@given(data())    
@pytest.mark.parametrize("m", monoids)
def test_associativity(m, data):
    t = type(m.identity)

    x: T = data.draw(from_type(t))
    y: T = data.draw(from_type(t))
    z: T = data.draw(from_type(t))

    xy: T = m.compose(x, y)
    yz: T = m.compose(y, z)

    assert m.compose(xy, z) == m.compose(x, yz)
        
import ipytest
ipytest.config(addopts=['-q'])
ipytest.run()
# Out:
# ......                                                                                       [100%]
# ========================================= warnings summary =========================================
# ../../.direnv/python-3.11.2/lib/python3.11/site-packages/_pytest/config/__init__.py:1173
#   /Users/rossfenning/garden/.direnv/python-3.11.2/lib/python3.11/site-packages/_pytest/config/__init__.py:1173: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: hypothesis
#     self._mark_plugins_for_rewrite(hook)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 6 passed, 1 warning in 0.44s
# <ExitCode.OK: 0>

# %%
from __future__ import annotations
from typing import Callable


U = TypeVar("U")
A = TypeVar("A")
B = TypeVar("B")


class Functor(Generic[T], metaclass=ABCMeta):
    @abstractmethod
    def map(t: T, f: Callable[A, B]) -> T[B]: pass

class Maybe(Functor[A], metaclass=ABCMeta):
    def map(m: Maybe, f): pass

class Nothing(Maybe[A]):
    def __init__(self, *args):
        pass
    def map(self: Maybe, _):
        return Nothing()
    def __eq__(self, _):
        return True
    def __str__(self):
        return '[Nothing]'
    
class Just(Maybe[A]):
    def __init__(self, x: A):
        self.x = x
    def map(self: Maybe, f: Callable[A, B]) -> Just[B]:
        return Just(f(self.x))
    def __eq__(self, y):
        return self.x == y
    def __str__(self):
        return f'[Just({self.x})]'


from hypothesis import given
from hypothesis.strategies import data, from_type, functions
from hypothesis import settings, Verbosity
import pytest
from typing import get_args


functors = [
    Nothing,
    Just,
]
types = [
    int,
    str,
    frozenset,
    bool,
]

identity = lambda x: x

@given(data())
@pytest.mark.parametrize("t", types)
@pytest.mark.parametrize("f", functors)
def test_identity(f: Functor, t: type, data):
    F = f[t]
    x = data.draw(from_type(t))
    
    print(F(x), F(x).map(identity))
    assert F(x) == F(x).map(identity)


@given(data())
@pytest.mark.parametrize("C", types)
@pytest.mark.parametrize("B", types)
@pytest.mark.parametrize("A", types)
@pytest.mark.parametrize("f", functors)
def test_composition(f: Functor, A: type, B:type, C: type, data):

    F = f[A]
    a: A = data.draw(from_type(A))

    def f_spec(x: A) -> B: pass
    f: Callable[A, B] = data.draw(functions(like=f_spec, returns=from_type(B), pure=True))

    def g_spec(y: B) -> C: pass
    g: Callable[b, c] = data.draw(functions(like=g_spec, returns=from_type(C), pure=True))
        
    def h(x: A) -> C:
        return g(f(x))

    assert F(a).map(h) == F(a).map(f).map(g)

@given(data())
@pytest.mark.parametrize("D", types)
@pytest.mark.parametrize("C", types)
@pytest.mark.parametrize("B", types)
@pytest.mark.parametrize("A", types)
@pytest.mark.parametrize("f", functors)
def test_associativity(f: Functor, A: type, B:type, C: type, D: type, data):
    F = f[A]
    a: A = data.draw(from_type(A))

    def f_spec(x: A) -> B: pass
    f: Callable[A, B] = data.draw(functions(like=f_spec, returns=from_type(B), pure=True))

    def g_spec(y: B) -> C: pass
    g: Callable[b, c] = data.draw(functions(like=g_spec, returns=from_type(C), pure=True))

    def h_spec(z: C) -> D: pass
    h: Callable[b, c] = data.draw(functions(like=h_spec, returns=from_type(D), pure=True))

    fg: Callable[A, C] = lambda x: g(f(x))
    gh: Callable[B, D] = lambda y: h(g(y))

    assert F(a).map(f).map(gh) == F(a).map(fg).map(h)
        
import ipytest
ipytest.run()
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.11.2, pytest-7.2.2, pluggy-1.0.0 -- /Users/rossfenning/garden/.direnv/python-3.11.2/bin/python3.11
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase('/Users/rossfenning/garden/Garden/notebooks/.hypothesis/examples')
# rootdir: /Users/rossfenning/garden/Garden/notebooks
# plugins: hypothesis-6.70.1, anyio-3.6.2
# collecting ... collected 648 items
#
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Nothing-int] PASSED                     [  0%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Nothing-str] PASSED                     [  0%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Nothing-frozenset] PASSED               [  0%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Nothing-bool] PASSED                    [  0%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Just-int] PASSED                        [  0%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Just-str] PASSED                        [  0%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Just-frozenset] PASSED                  [  1%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_identity[Just-bool] PASSED                       [  1%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-int-int] PASSED          [  1%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-int-str] PASSED          [  1%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-int-frozenset] PASSED    [  1%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-int-bool] PASSED         [  1%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-str-int] PASSED          [  2%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-str-str] PASSED          [  2%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-str-frozenset] PASSED    [  2%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-str-bool] PASSED         [  2%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-frozenset-int] PASSED    [  2%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-frozenset-str] PASSED    [  2%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-frozenset-frozenset] PASSED [  2%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-frozenset-bool] PASSED   [  3%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-bool-int] PASSED         [  3%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-bool-str] PASSED         [  3%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-bool-frozenset] PASSED   [  3%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-int-bool-bool] PASSED        [  3%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-int-int] PASSED          [  3%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-int-str] PASSED          [  4%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-int-frozenset] PASSED    [  4%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-int-bool] PASSED         [  4%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-str-int] PASSED          [  4%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-str-str] PASSED          [  4%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-str-frozenset] PASSED    [  4%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-str-bool] PASSED         [  4%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-frozenset-int] PASSED    [  5%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-frozenset-str] PASSED    [  5%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-frozenset-frozenset] PASSED [  5%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-frozenset-bool] PASSED   [  5%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-bool-int] PASSED         [  5%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-bool-str] PASSED         [  5%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-bool-frozenset] PASSED   [  6%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-str-bool-bool] PASSED        [  6%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-int-int] PASSED    [  6%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-int-str] PASSED    [  6%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-int-frozenset] PASSED [  6%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-int-bool] PASSED   [  6%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-str-int] PASSED    [  6%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-str-str] PASSED    [  7%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-str-frozenset] PASSED [  7%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-str-bool] PASSED   [  7%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-frozenset-int] PASSED [  7%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-frozenset-str] PASSED [  7%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-frozenset-frozenset] PASSED [  7%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-frozenset-bool] PASSED [  8%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-bool-int] PASSED   [  8%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-bool-str] PASSED   [  8%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-bool-frozenset] PASSED [  8%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-frozenset-bool-bool] PASSED  [  8%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-int-int] PASSED         [  8%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-int-str] PASSED         [  8%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-int-frozenset] PASSED   [  9%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-int-bool] PASSED        [  9%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-str-int] PASSED         [  9%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-str-str] PASSED         [  9%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-str-frozenset] PASSED   [  9%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-str-bool] PASSED        [  9%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-frozenset-int] PASSED   [ 10%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-frozenset-str] PASSED   [ 10%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-frozenset-frozenset] PASSED [ 10%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-frozenset-bool] PASSED  [ 10%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-bool-int] PASSED        [ 10%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-bool-str] PASSED        [ 10%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-bool-frozenset] PASSED  [ 10%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Nothing-bool-bool-bool] PASSED       [ 11%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-int-int] PASSED             [ 11%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-int-str] PASSED             [ 11%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-int-frozenset] PASSED       [ 11%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-int-bool] PASSED            [ 11%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-str-int] PASSED             [ 11%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-str-str] PASSED             [ 12%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-str-frozenset] PASSED       [ 12%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-str-bool] PASSED            [ 12%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-frozenset-int] PASSED       [ 12%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-frozenset-str] PASSED       [ 12%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-frozenset-frozenset] PASSED [ 12%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-frozenset-bool] PASSED      [ 12%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-bool-int] PASSED            [ 13%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-bool-str] PASSED            [ 13%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-bool-frozenset] PASSED      [ 13%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-int-bool-bool] PASSED           [ 13%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-int-int] PASSED             [ 13%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-int-str] PASSED             [ 13%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-int-frozenset] PASSED       [ 14%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-int-bool] PASSED            [ 14%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-str-int] PASSED             [ 14%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-str-str] PASSED             [ 14%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-str-frozenset] PASSED       [ 14%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-str-bool] PASSED            [ 14%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-frozenset-int] PASSED       [ 14%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-frozenset-str] PASSED       [ 15%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-frozenset-frozenset] PASSED [ 15%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-frozenset-bool] PASSED      [ 15%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-bool-int] PASSED            [ 15%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-bool-str] PASSED            [ 15%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-bool-frozenset] PASSED      [ 15%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-str-bool-bool] PASSED           [ 16%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-int-int] PASSED       [ 16%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-int-str] PASSED       [ 16%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-int-frozenset] PASSED [ 16%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-int-bool] PASSED      [ 16%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-str-int] PASSED       [ 16%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-str-str] PASSED       [ 16%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-str-frozenset] PASSED [ 17%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-str-bool] PASSED      [ 17%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-frozenset-int] PASSED [ 17%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-frozenset-str] PASSED [ 17%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-frozenset-frozenset] PASSED [ 17%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-frozenset-bool] PASSED [ 17%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-bool-int] PASSED      [ 18%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-bool-str] PASSED      [ 18%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-bool-frozenset] PASSED [ 18%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-frozenset-bool-bool] PASSED     [ 18%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-int-int] PASSED            [ 18%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-int-str] PASSED            [ 18%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-int-frozenset] PASSED      [ 18%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-int-bool] PASSED           [ 19%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-str-int] PASSED            [ 19%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-str-str] PASSED            [ 19%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-str-frozenset] PASSED      [ 19%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-str-bool] PASSED           [ 19%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-frozenset-int] PASSED      [ 19%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-frozenset-str] PASSED      [ 20%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-frozenset-frozenset] PASSED [ 20%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-frozenset-bool] PASSED     [ 20%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-bool-int] PASSED           [ 20%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-bool-str] PASSED           [ 20%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-bool-frozenset] PASSED     [ 20%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_composition[Just-bool-bool-bool] PASSED          [ 20%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-int-int] PASSED    [ 21%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-int-str] PASSED    [ 21%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-int-frozenset] PASSED [ 21%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-int-bool] PASSED   [ 21%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-str-int] PASSED    [ 21%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-str-str] PASSED    [ 21%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-str-frozenset] PASSED [ 22%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-str-bool] PASSED   [ 22%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-frozenset-int] PASSED [ 22%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-frozenset-str] PASSED [ 22%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-frozenset-frozenset] PASSED [ 22%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-frozenset-bool] PASSED [ 22%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-bool-int] PASSED   [ 22%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-bool-str] PASSED   [ 23%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-bool-frozenset] PASSED [ 23%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-int-bool-bool] PASSED  [ 23%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-int-int] PASSED    [ 23%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-int-str] PASSED    [ 23%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-int-frozenset] PASSED [ 23%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-int-bool] PASSED   [ 24%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-str-int] PASSED    [ 24%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-str-str] PASSED    [ 24%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-str-frozenset] PASSED [ 24%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-str-bool] PASSED   [ 24%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-frozenset-int] PASSED [ 24%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-frozenset-str] PASSED [ 25%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-frozenset-frozenset] PASSED [ 25%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-frozenset-bool] PASSED [ 25%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-bool-int] PASSED   [ 25%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-bool-str] PASSED   [ 25%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-bool-frozenset] PASSED [ 25%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-str-bool-bool] PASSED  [ 25%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-int-int] PASSED [ 26%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-int-str] PASSED [ 26%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-int-frozenset] PASSED [ 26%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-int-bool] PASSED [ 26%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-str-int] PASSED [ 26%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-str-str] PASSED [ 26%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-str-frozenset] PASSED [ 27%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-str-bool] PASSED [ 27%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-frozenset-int] PASSED [ 27%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-frozenset-str] PASSED [ 27%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-frozenset-frozenset] PASSED [ 27%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-frozenset-bool] PASSED [ 27%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-bool-int] PASSED [ 27%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-bool-str] PASSED [ 28%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-bool-frozenset] PASSED [ 28%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-frozenset-bool-bool] PASSED [ 28%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-int-int] PASSED   [ 28%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-int-str] PASSED   [ 28%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-int-frozenset] PASSED [ 28%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-int-bool] PASSED  [ 29%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-str-int] PASSED   [ 29%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-str-str] PASSED   [ 29%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-str-frozenset] PASSED [ 29%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-str-bool] PASSED  [ 29%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-frozenset-int] PASSED [ 29%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-frozenset-str] PASSED [ 29%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-frozenset-frozenset] PASSED [ 30%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-frozenset-bool] PASSED [ 30%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-bool-int] PASSED  [ 30%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-bool-str] PASSED  [ 30%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-bool-frozenset] PASSED [ 30%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-int-bool-bool-bool] PASSED [ 30%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-int-int] PASSED    [ 31%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-int-str] PASSED    [ 31%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-int-frozenset] PASSED [ 31%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-int-bool] PASSED   [ 31%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-str-int] PASSED    [ 31%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-str-str] PASSED    [ 31%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-str-frozenset] PASSED [ 31%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-str-bool] PASSED   [ 32%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-frozenset-int] PASSED [ 32%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-frozenset-str] PASSED [ 32%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-frozenset-frozenset] PASSED [ 32%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-frozenset-bool] PASSED [ 32%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-bool-int] PASSED   [ 32%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-bool-str] PASSED   [ 33%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-bool-frozenset] PASSED [ 33%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-int-bool-bool] PASSED  [ 33%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-int-int] PASSED    [ 33%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-int-str] PASSED    [ 33%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-int-frozenset] PASSED [ 33%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-int-bool] PASSED   [ 33%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-str-int] PASSED    [ 34%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-str-str] PASSED    [ 34%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-str-frozenset] PASSED [ 34%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-str-bool] PASSED   [ 34%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-frozenset-int] PASSED [ 34%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-frozenset-str] PASSED [ 34%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-frozenset-frozenset] PASSED [ 35%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-frozenset-bool] PASSED [ 35%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-bool-int] PASSED   [ 35%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-bool-str] PASSED   [ 35%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-bool-frozenset] PASSED [ 35%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-str-bool-bool] PASSED  [ 35%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-int-int] PASSED [ 35%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-int-str] PASSED [ 36%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-int-frozenset] PASSED [ 36%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-int-bool] PASSED [ 36%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-str-int] PASSED [ 36%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-str-str] PASSED [ 36%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-str-frozenset] PASSED [ 36%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-str-bool] PASSED [ 37%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-frozenset-int] PASSED [ 37%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-frozenset-str] PASSED [ 37%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-frozenset-frozenset] PASSED [ 37%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-frozenset-bool] PASSED [ 37%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-bool-int] PASSED [ 37%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-bool-str] PASSED [ 37%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-bool-frozenset] PASSED [ 38%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-frozenset-bool-bool] PASSED [ 38%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-int-int] PASSED   [ 38%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-int-str] PASSED   [ 38%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-int-frozenset] PASSED [ 38%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-int-bool] PASSED  [ 38%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-str-int] PASSED   [ 39%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-str-str] PASSED   [ 39%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-str-frozenset] PASSED [ 39%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-str-bool] PASSED  [ 39%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-frozenset-int] PASSED [ 39%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-frozenset-str] PASSED [ 39%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-frozenset-frozenset] PASSED [ 39%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-frozenset-bool] PASSED [ 40%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-bool-int] PASSED  [ 40%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-bool-str] PASSED  [ 40%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-bool-frozenset] PASSED [ 40%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-str-bool-bool-bool] PASSED [ 40%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-int-int] PASSED [ 40%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-int-str] PASSED [ 41%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-int-frozenset] PASSED [ 41%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-int-bool] PASSED [ 41%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-str-int] PASSED [ 41%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-str-str] PASSED [ 41%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-str-frozenset] PASSED [ 41%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-str-bool] PASSED [ 41%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-frozenset-int] PASSED [ 42%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-frozenset-str] PASSED [ 42%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-frozenset-frozenset] PASSED [ 42%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-frozenset-bool] PASSED [ 42%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-bool-int] PASSED [ 42%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-bool-str] PASSED [ 42%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-bool-frozenset] PASSED [ 43%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-int-bool-bool] PASSED [ 43%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-int-int] PASSED [ 43%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-int-str] PASSED [ 43%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-int-frozenset] PASSED [ 43%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-int-bool] PASSED [ 43%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-str-int] PASSED [ 43%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-str-str] PASSED [ 44%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-str-frozenset] PASSED [ 44%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-str-bool] PASSED [ 44%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-frozenset-int] PASSED [ 44%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-frozenset-str] PASSED [ 44%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-frozenset-frozenset] PASSED [ 44%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-frozenset-bool] PASSED [ 45%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-bool-int] PASSED [ 45%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-bool-str] PASSED [ 45%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-bool-frozenset] PASSED [ 45%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-str-bool-bool] PASSED [ 45%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-int-int] PASSED [ 45%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-int-str] PASSED [ 45%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-int-frozenset] PASSED [ 46%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-int-bool] PASSED [ 46%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-str-int] PASSED [ 46%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-str-str] PASSED [ 46%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-str-frozenset] PASSED [ 46%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-str-bool] PASSED [ 46%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-frozenset-int] PASSED [ 47%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-frozenset-str] PASSED [ 47%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-frozenset-frozenset] PASSED [ 47%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-frozenset-bool] PASSED [ 47%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-bool-int] PASSED [ 47%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-bool-str] PASSED [ 47%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-bool-frozenset] PASSED [ 47%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-frozenset-bool-bool] PASSED [ 48%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-int-int] PASSED [ 48%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-int-str] PASSED [ 48%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-int-frozenset] PASSED [ 48%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-int-bool] PASSED [ 48%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-str-int] PASSED [ 48%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-str-str] PASSED [ 49%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-str-frozenset] PASSED [ 49%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-str-bool] PASSED [ 49%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-frozenset-int] PASSED [ 49%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-frozenset-str] PASSED [ 49%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-frozenset-frozenset] PASSED [ 49%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-frozenset-bool] PASSED [ 50%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-bool-int] PASSED [ 50%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-bool-str] PASSED [ 50%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-bool-frozenset] PASSED [ 50%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-frozenset-bool-bool-bool] PASSED [ 50%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-int-int] PASSED   [ 50%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-int-str] PASSED   [ 50%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-int-frozenset] PASSED [ 51%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-int-bool] PASSED  [ 51%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-str-int] PASSED   [ 51%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-str-str] PASSED   [ 51%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-str-frozenset] PASSED [ 51%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-str-bool] PASSED  [ 51%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-frozenset-int] PASSED [ 52%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-frozenset-str] PASSED [ 52%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-frozenset-frozenset] PASSED [ 52%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-frozenset-bool] PASSED [ 52%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-bool-int] PASSED  [ 52%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-bool-str] PASSED  [ 52%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-bool-frozenset] PASSED [ 52%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-int-bool-bool] PASSED [ 53%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-int-int] PASSED   [ 53%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-int-str] PASSED   [ 53%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-int-frozenset] PASSED [ 53%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-int-bool] PASSED  [ 53%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-str-int] PASSED   [ 53%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-str-str] PASSED   [ 54%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-str-frozenset] PASSED [ 54%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-str-bool] PASSED  [ 54%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-frozenset-int] PASSED [ 54%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-frozenset-str] PASSED [ 54%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-frozenset-frozenset] PASSED [ 54%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-frozenset-bool] PASSED [ 54%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-bool-int] PASSED  [ 55%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-bool-str] PASSED  [ 55%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-bool-frozenset] PASSED [ 55%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-str-bool-bool] PASSED [ 55%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-int-int] PASSED [ 55%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-int-str] PASSED [ 55%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-int-frozenset] PASSED [ 56%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-int-bool] PASSED [ 56%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-str-int] PASSED [ 56%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-str-str] PASSED [ 56%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-str-frozenset] PASSED [ 56%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-str-bool] PASSED [ 56%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-frozenset-int] PASSED [ 56%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-frozenset-str] PASSED [ 57%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-frozenset-frozenset] PASSED [ 57%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-frozenset-bool] PASSED [ 57%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-bool-int] PASSED [ 57%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-bool-str] PASSED [ 57%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-bool-frozenset] PASSED [ 57%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-frozenset-bool-bool] PASSED [ 58%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-int-int] PASSED  [ 58%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-int-str] PASSED  [ 58%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-int-frozenset] PASSED [ 58%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-int-bool] PASSED [ 58%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-str-int] PASSED  [ 58%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-str-str] PASSED  [ 58%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-str-frozenset] PASSED [ 59%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-str-bool] PASSED [ 59%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-frozenset-int] PASSED [ 59%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-frozenset-str] PASSED [ 59%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-frozenset-frozenset] PASSED [ 59%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-frozenset-bool] PASSED [ 59%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-bool-int] PASSED [ 60%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-bool-str] PASSED [ 60%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-bool-frozenset] PASSED [ 60%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Nothing-bool-bool-bool-bool] PASSED [ 60%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-int-int] PASSED       [ 60%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-int-str] PASSED       [ 60%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-int-frozenset] PASSED [ 60%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-int-bool] PASSED      [ 61%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-str-int] PASSED       [ 61%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-str-str] PASSED       [ 61%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-str-frozenset] PASSED [ 61%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-str-bool] PASSED      [ 61%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-frozenset-int] PASSED [ 61%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-frozenset-str] PASSED [ 62%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-frozenset-frozenset] PASSED [ 62%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-frozenset-bool] PASSED [ 62%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-bool-int] PASSED      [ 62%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-bool-str] PASSED      [ 62%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-bool-frozenset] PASSED [ 62%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-int-bool-bool] PASSED     [ 62%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-int-int] PASSED       [ 63%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-int-str] PASSED       [ 63%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-int-frozenset] PASSED [ 63%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-int-bool] PASSED      [ 63%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-str-int] PASSED       [ 63%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-str-str] PASSED       [ 63%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-str-frozenset] PASSED [ 64%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-str-bool] PASSED      [ 64%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-frozenset-int] PASSED [ 64%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-frozenset-str] PASSED [ 64%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-frozenset-frozenset] PASSED [ 64%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-frozenset-bool] PASSED [ 64%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-bool-int] PASSED      [ 64%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-bool-str] PASSED      [ 65%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-bool-frozenset] PASSED [ 65%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-str-bool-bool] PASSED     [ 65%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-int-int] PASSED [ 65%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-int-str] PASSED [ 65%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-int-frozenset] PASSED [ 65%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-int-bool] PASSED [ 66%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-str-int] PASSED [ 66%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-str-str] PASSED [ 66%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-str-frozenset] PASSED [ 66%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-str-bool] PASSED [ 66%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-frozenset-int] PASSED [ 66%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-frozenset-str] PASSED [ 66%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-frozenset-frozenset] PASSED [ 67%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-frozenset-bool] PASSED [ 67%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-bool-int] PASSED [ 67%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-bool-str] PASSED [ 67%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-bool-frozenset] PASSED [ 67%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-frozenset-bool-bool] PASSED [ 67%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-int-int] PASSED      [ 68%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-int-str] PASSED      [ 68%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-int-frozenset] PASSED [ 68%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-int-bool] PASSED     [ 68%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-str-int] PASSED      [ 68%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-str-str] PASSED      [ 68%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-str-frozenset] PASSED [ 68%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-str-bool] PASSED     [ 69%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-frozenset-int] PASSED [ 69%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-frozenset-str] PASSED [ 69%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-frozenset-frozenset] PASSED [ 69%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-frozenset-bool] PASSED [ 69%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-bool-int] PASSED     [ 69%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-bool-str] PASSED     [ 70%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-bool-frozenset] PASSED [ 70%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-int-bool-bool-bool] PASSED    [ 70%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-int-int-int] PASSED       [ 70%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-int-int-str] PASSED       [ 70%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-int-int-frozenset] PASSED [ 70%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-int-int-bool] PASSED      [ 70%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-int-str-int] PASSED       [ 71%]
# ...
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-frozenset-bool-int] PASSED [ 77%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-frozenset-bool-str] PASSED [ 77%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-frozenset-bool-frozenset] PASSED [ 77%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-frozenset-bool-bool] PASSED [ 77%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-int-int] PASSED      [ 77%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-int-str] PASSED      [ 78%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-int-frozenset] PASSED [ 78%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-int-bool] PASSED     [ 78%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-str-int] PASSED      [ 78%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-str-str] PASSED      [ 78%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-str-frozenset] PASSED [ 78%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-str-bool] PASSED     [ 79%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-frozenset-int] PASSED [ 79%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-frozenset-str] PASSED [ 79%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-frozenset-frozenset] PASSED [ 79%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-frozenset-bool] PASSED [ 79%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-bool-int] PASSED     [ 79%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-bool-str] PASSED     [ 79%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-bool-frozenset] PASSED [ 80%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-str-bool-bool-bool] PASSED    [ 80%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-int-int] PASSED [ 80%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-int-str] PASSED [ 80%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-int-frozenset] PASSED [ 80%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-int-bool] PASSED [ 80%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-str-int] PASSED [ 81%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-str-str] PASSED [ 81%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-str-frozenset] PASSED [ 81%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-str-bool] PASSED [ 81%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-frozenset-int] PASSED [ 81%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-frozenset-str] PASSED [ 81%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-frozenset-frozenset] PASSED [ 81%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-frozenset-bool] PASSED [ 82%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-bool-int] PASSED [ 82%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-bool-str] PASSED [ 82%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-bool-frozenset] PASSED [ 82%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-int-bool-bool] PASSED [ 82%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-int-int] PASSED [ 82%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-int-str] PASSED [ 83%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-int-frozenset] PASSED [ 83%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-int-bool] PASSED [ 83%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-str-int] PASSED [ 83%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-str-str] PASSED [ 83%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-str-frozenset] PASSED [ 83%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-str-bool] PASSED [ 83%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-frozenset-int] PASSED [ 84%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-frozenset-str] PASSED [ 84%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-frozenset-frozenset] PASSED [ 84%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-frozenset-bool] PASSED [ 84%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-bool-int] PASSED [ 84%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-bool-str] PASSED [ 84%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-bool-frozenset] PASSED [ 85%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-str-bool-bool] PASSED [ 85%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-int-int] PASSED [ 85%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-int-str] PASSED [ 85%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-int-frozenset] PASSED [ 85%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-int-bool] PASSED [ 85%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-str-int] PASSED [ 85%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-str-str] PASSED [ 86%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-str-frozenset] PASSED [ 86%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-str-bool] PASSED [ 86%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-frozenset-int] PASSED [ 86%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-frozenset-str] PASSED [ 86%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-frozenset-frozenset] PASSED [ 86%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-frozenset-bool] PASSED [ 87%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-bool-int] PASSED [ 87%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-bool-str] PASSED [ 87%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-bool-frozenset] PASSED [ 87%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-frozenset-bool-bool] PASSED [ 87%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-int-int] PASSED [ 87%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-int-str] PASSED [ 87%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-int-frozenset] PASSED [ 88%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-int-bool] PASSED [ 88%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-str-int] PASSED [ 88%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-str-str] PASSED [ 88%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-str-frozenset] PASSED [ 88%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-str-bool] PASSED [ 88%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-frozenset-int] PASSED [ 89%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-frozenset-str] PASSED [ 89%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-frozenset-frozenset] PASSED [ 89%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-frozenset-bool] PASSED [ 89%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-bool-int] PASSED [ 89%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-bool-str] PASSED [ 89%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-bool-frozenset] PASSED [ 89%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-frozenset-bool-bool-bool] PASSED [ 90%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-int-int] PASSED      [ 90%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-int-str] PASSED      [ 90%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-int-frozenset] PASSED [ 90%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-int-bool] PASSED     [ 90%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-str-int] PASSED      [ 90%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-str-str] PASSED      [ 91%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-str-frozenset] PASSED [ 91%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-str-bool] PASSED     [ 91%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-frozenset-int] PASSED [ 91%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-frozenset-str] PASSED [ 91%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-frozenset-frozenset] PASSED [ 91%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-frozenset-bool] PASSED [ 91%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-bool-int] PASSED     [ 92%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-bool-str] PASSED     [ 92%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-bool-frozenset] PASSED [ 92%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-int-bool-bool] PASSED    [ 92%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-int-int] PASSED      [ 92%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-int-str] PASSED      [ 92%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-int-frozenset] PASSED [ 93%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-int-bool] PASSED     [ 93%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-str-int] PASSED      [ 93%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-str-str] PASSED      [ 93%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-str-frozenset] PASSED [ 93%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-str-bool] PASSED     [ 93%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-frozenset-int] PASSED [ 93%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-frozenset-str] PASSED [ 94%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-frozenset-frozenset] PASSED [ 94%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-frozenset-bool] PASSED [ 94%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-bool-int] PASSED     [ 94%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-bool-str] PASSED     [ 94%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-bool-frozenset] PASSED [ 94%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-str-bool-bool] PASSED    [ 95%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-int-int] PASSED [ 95%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-int-str] PASSED [ 95%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-int-frozenset] PASSED [ 95%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-int-bool] PASSED [ 95%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-str-int] PASSED [ 95%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-str-str] PASSED [ 95%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-str-frozenset] PASSED [ 96%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-str-bool] PASSED [ 96%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-frozenset-int] PASSED [ 96%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-frozenset-str] PASSED [ 96%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-frozenset-frozenset] PASSED [ 96%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-frozenset-bool] PASSED [ 96%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-bool-int] PASSED [ 97%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-bool-str] PASSED [ 97%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-bool-frozenset] PASSED [ 97%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-frozenset-bool-bool] PASSED [ 97%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-int-int] PASSED     [ 97%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-int-str] PASSED     [ 97%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-int-frozenset] PASSED [ 97%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-int-bool] PASSED    [ 98%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-str-int] PASSED     [ 98%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-str-str] PASSED     [ 98%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-str-frozenset] PASSED [ 98%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-str-bool] PASSED    [ 98%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-frozenset-int] PASSED [ 98%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-frozenset-str] PASSED [ 99%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-frozenset-frozenset] PASSED [ 99%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-frozenset-bool] PASSED [ 99%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-bool-int] PASSED    [ 99%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-bool-str] PASSED    [ 99%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-bool-frozenset] PASSED [ 99%]
# t_6b2f6fc5a9054262816137f1764062b3.py::test_associativity[Just-bool-bool-bool-bool] PASSED   [100%]
#
# ========================================= warnings summary =========================================
# ../../.direnv/python-3.11.2/lib/python3.11/site-packages/_pytest/config/__init__.py:1173
#   /Users/rossfenning/garden/.direnv/python-3.11.2/lib/python3.11/site-packages/_pytest/config/__init__.py:1173: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: hypothesis
#     self._mark_plugins_for_rewrite(hook)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================================= 648 passed, 1 warning in 56.44s ==================================
# <ExitCode.OK: 0>
